# %%
import pandas as pd

# %%
app_train = pd.read_csv(r'application_train_all_models_final.csv', index_col=0)
prev_agg = pd.read_csv(r'prev_app_agg.csv')
app_train = app_train.merge(prev_agg, on='SK_ID_CURR', how='left')

prev_cols = [c for c in prev_agg.columns if c != 'SK_ID_CURR']
app_train[prev_cols] = app_train[prev_cols].fillna(0)

# %%
app_train.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY',
#        ...
#        'prev_credit_ratio_min', 'prev_down_payment_mean',
#        'prev_days_decision_mean', 'prev_days_decision_min',
#        'prev_days_decision_max', 'prev_days_last_due_mean',
#        'prev_cnt_payment_mean', 'prev_cnt_payment_max', 'prev_insured_mean',
#        'has_prev_app'],
#       dtype='object', length=115)

# %%
app_train.to_csv(r"application_train_all_models_final_2.csv")
